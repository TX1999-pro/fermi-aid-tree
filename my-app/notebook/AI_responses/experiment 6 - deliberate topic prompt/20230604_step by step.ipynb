# %% [markdown]
# # Experiment 0604 - estimation problem solving step by step

# %%
# dependency
# %pip install python-dotenv
# %pip install openai
# %pip install pandas

# %%
import os
from dotenv import load_dotenv, find_dotenv # load keys from .env file
import openai # use OpenAI API
import random
import re
import json
import pandas as pd
import numpy as np
import datetime
import tiktoken

_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key  = os.getenv('OPENAI_API_KEY')
encoding = tiktoken.get_encoding("cl100k_base")

# %%
encoding = tiktoken.encoding_for_model("gpt-4")

def num_tokens_from_messages(messages, model="gpt-4"):
    """Returns the number of tokens used by a list of messages."""
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        print("Warning: model not found. Using cl100k_base encoding.")
        encoding = tiktoken.get_encoding("cl100k_base")
    if model == "gpt-3.5-turbo":
        print("Warning: gpt-3.5-turbo may change over time. Returning num tokens assuming gpt-3.5-turbo-0301.")
        return num_tokens_from_messages(messages, model="gpt-3.5-turbo-0301")
    elif model == "gpt-4":
        print("Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.")
        return num_tokens_from_messages(messages, model="gpt-4-0314")
    elif model == "gpt-3.5-turbo-0301":
        tokens_per_message = 4  # every message follows <|start|>{role/name}\n{content}<|end|>\n
        tokens_per_name = -1  # if there's a name, the role is omitted
    elif model == "gpt-4-0314":
        tokens_per_message = 3
        tokens_per_name = 1
    else:
        raise NotImplementedError(f"""num_tokens_from_messages() is not implemented for model {model}. See https://github.com/openai/openai-python/blob/main/chatml.md for information on how messages are converted to tokens.""")
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3  # every reply is primed with <|start|>assistant<|message|>
    return num_tokens

# %%
# search for the json object at the end using regular expressions
def get_json(text):
    '''extract the json object from the text using regular expressions'''
    match = re.search(r'{.*}', text)
    if match:
        json_string = match.group()
        # json_object = json.loads(json_string)
        return json_string

def get_python(text):
    '''extract the python code from the text using regular expressions'''
    pattern = re.compile(r'"""python(.*?)"""', re.DOTALL)
    match = pattern.search(text)
    if match:
        code = match.group(1)
        return code.strip()
    else:
        return None

def get_completion(prompt, model="gpt-3.5-turbo"):
    '''Query OpenAI API to get a completion from a naive prompt'''
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
        max_tokens=500, # this is the maximum number of returned tokens
    )
    print(">>>>RESPONSE>>>>")
    print(str(response.choices[0].message["content"]))
    print("<<<<END<<<<")
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    '''ChatML format to query OpenAI API to get a completion from a list of messages'''
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=2500,
    )
    return response.choices[0].message["content"]

# write function to combine two messages
# turn the above process into a function
def get_answer_step_by_step(question, model="gpt-4", get_completion_from_messages=get_completion_from_messages):
    '''Query OpenAI API to answer a question step-by-step'''
    system_message = """A user will give you a problem. Follow these steps.

Step 1: Reason step-by-step to clearly define the problem and what additional information is desired.

Step 2: Reason step-by-step a methodology that can be used to answer the problem.

Step 3: Calculate the results based on step 2.

Step 4: Stating assumptions used in the methodology and the results.

    """
    messages = [{"role": "system", "content": system_message},
    {"role": "user", "content": question}]
    result = get_completion_from_messages(messages, model=model) # returns a string
    return result

def text_to_json(message, model="gpt-3.5"):
    '''Query OpenAI API to convert text to a parsable JSON'''
    JSON_Parser_system_message = '''\
A user will give you a text contain 4 steps. Your task is to convert the text to make it more readable. Each step will be the key, and the details will be the value.
Your output will be a JSON object in deliminator (""") looks like this: 
JSON={"Step 1": "details in step 1", "Step 2": "details in step 2", "Step 3": "details in step 3", "Step 4": "details in step 4"}
Here's an example:
INPUT:
======
Step 1: 
To answer this problem, we need to know the following information:
1. How much power is required to jump start a car?
2. How much power can be generated by one lemon battery?
3. How many lemon batteries are required to generate the power needed to jump start a car?

Step 2:
To answer this problem, we can follow these steps:
1. Determine the power required to jump start a car.
2. Determine the power generated by one lemon battery.
3. Calculate the number of lemon batteries required to generate the power needed to jump start a car.

Step 3:
1. According to AAA, the power required to jump start a car is around 300-400 amps for 5-10 seconds. Let's assume that we need 350 amps for 7 seconds to jump start a car.
2. One lemon battery can generate around 0.7 volts and 0.0003 amps of current. Using Ohm's law, we can calculate the power generated by one lemon battery as follows: Power = Voltage x Current = 0.7 x 0.0003 = 0.00021 watts or 0.21 milliwatts.
3. To generate 350 amps for 7 seconds, we need a total power of 350 x 7 = 2450 watts or 2.45 kilowatts. To generate this much power using lemon batteries, we need 2.45 / 0.00021 = 11,666.67 lemon batteries.

Step 4:
Assumptions:
1. The power required to jump start a car is assumed to be 350 amps for 7 seconds.
2. The power generated by one lemon battery is assumed to be 0.21 milliwatts.
3. The lemon batteries are assumed to be connected in series to generate the required voltage and current.

======
OUTPUT:"""
JSON={"problem definition": "If a lemon can be made into a battery, how many lemons can jump start a car?", "methodology": "To answer this problem, we need to know the power required to jump start a car, the power generated by one lemon battery, and the number of lemon batteries required to generate the power needed to jump start a car. We can calculate the number of lemon batteries required by dividing the required power by the power generated by one lemon battery.", "results": "To jump start a car, we need 11,666.67 lemon batteries.", "assumptions": "The power required to jump start a car is assumed to be 350 amps for 7 seconds. The power generated by one lemon battery is assumed to be 0.21 milliwatts. The lemon batteries are assumed to be connected in series to generate the required voltage and current."}
"""
'''
    message_wrapper = f'''Convert message into JSON object.\nInput:\n==={message}\n===\n OUTPUT:\n """[JSON=]"""'''
    get_json_messages = [{"role": "system", "content": JSON_Parser_system_message},
    {"role": "user", "content": message_wrapper}]

    JSON_result = get_completion_from_messages(get_json_messages) # returns a string
    return JSON_result

def text_to_python(message, model="gpt-4"):
    '''Query OpenAI API to convert text to python'''
    Python_generator_system_message = '''A user will give you a text contain 4 steps. Your task is to edit the text to make it more readable in the following format.
Output a JSON object after deliminator """ in the following structure: JSON={"Step 1": "details in step 1", "Step 2": "details in step 2", "Step 3": "details in step 3", "Step 4": "details in step 4"}
One Example is as follows:
INPUT TEXT:
Step 1: 
To answer this problem, we need to know the following information:
1. How much power is required to jump start a car?
2. How much power can be generated by one lemon battery?
3. How many lemon batteries are required to generate the power needed to jump start a car?

Step 2:
To answer this problem, we can follow these steps:
1. Determine the power required to jump start a car.
2. Determine the power generated by one lemon battery.
3. Calculate the number of lemon batteries required to generate the power needed to jump start a car.

Step 3:
1. According to AAA, the power required to jump start a car is around 300-400 amps for 5-10 seconds. Let's assume that we need 350 amps for 7 seconds to jump start a car.
2. One lemon battery can generate around 0.7 volts and 0.0003 amps of current. Using Ohm's law, we can calculate the power generated by one lemon battery as follows: Power = Voltage x Current = 0.7 x 0.0003 = 0.00021 watts or 0.21 milliwatts.
3. To generate 350 amps for 7 seconds, we need a total power of 350 x 7 = 2450 watts or 2.45 kilowatts. To generate this much power using lemon batteries, we need 2.45 / 0.00021 = 11,666.67 lemon batteries.

Step 4:
Assumptions:
1. The power required to jump start a car is assumed to be 350 amps for 7 seconds.
2. The power generated by one lemon battery is assumed to be 0.21 milliwatts.
3. The lemon batteries are assumed to be connected in series to generate the required voltage and current.

OUTPUT PYTHON:
"""python
    # Step 1: Define the variables
    power_car_jump_start_amps = 350    # Amps
    time_car_jump_start_seconds = 7    # Seconds

    lemon_battery_volts = 0.7          # Volts
    lemon_battery_amps = 0.0003        # Amps

    # Step 2: Calculate the power required to jump start a car and the power generated by one lemon battery

    # Power = Voltage x Current
    power_car_jump_start_watts = power_car_jump_start_amps * time_car_jump_start_seconds  # Watts
    power_lemon_battery_watts = lemon_battery_volts * lemon_battery_amps  # Watts

    # Step 3: Calculate the number of lemon batteries required to generate the power needed to jump start a car
    number_of_lemon_batteries = power_car_jump_start_watts / power_lemon_battery_watts

    # Step 4: Print the result
    print(f"You need approximately {number_of_lemon_batteries:.0f} lemon batteries to jump start a car.")
"""
Your will only output the python code after """ in the following format:
"""python
# Step 1: Define the variables
# ...
# Last step: Print the result
print(f"...")
"""
'''
    get_python_messages = [{"role": "system", "content": Python_generator_system_message},
    {"role": "user", "content": message}]
    result = get_completion_from_messages(get_python_messages, model=model) # returns a string
    return result
# # Example of an OpenAI ChatCompletion request with stream=True
# # https://platform.openai.com/docs/guides/chat

# # a ChatCompletion request

# %%
# Uncomment and Run this code block to get an example output

# prompt_example= f"""What is Fermi Estimation and how does it work?"""
# response = get_completion(prompt_example)

# %%
# market sizing question generator
# list of service providers
service_providers = ["piano tuners", "nurseries", "coffee shops", "restaurants", "libraries", "gyms", "hotels", "barber shops", "gas stations", "schools"]

# list of cities
cities = ["Chicago", "London", "Beijing", "New York", "Los Angeles", "Paris", "Berlin", "Tokyo", "Sydney", "Mumbai"]

# function to generate a question
def generate_market_sizing_question():
    service_provider = random.choice(service_providers)
    city = random.choice(cities)
    
    question = f"How many {service_provider} are there in {city}?"
    
    return question

# generate a question
print(generate_market_sizing_question())
# Out:
# How many restaurants are there in London?

# %%
# warm up talk
# turn the above process into a function
you_are_fermi = "Your name is Enrico Fermi. You are an expert physicist and mathematician. You are known for your ability to make good approximate calculations with little or no actual data. You are also known for your ability to solve problems using recursion."
round_1_fermi = '''Hi Fermi, are you alright? I want to learn how to use your trick to do Fermi Estimation and improve my problem solving skills.'''
round_1_response = '''Fermi estimation, also known as Fermi problems, is a way to make good approximate calculations with little or no actual data. The method is named after physicist Enrico Fermi as he was known for making good approximate calculations with little or no actual data.

Fermi problems typically involve making reasonable assumptions about the problem, then performing simple calculations on those assumptions. Here's a step-by-step guide on how to apply this:

1. Define the Problem Clearly: Start by identifying the problem you need to solve. Fermi problems often seem overwhelming at first glance due to the large numbers and broad scope involved. For example, "How many piano tuners are there in New York City?".

2. Break Down the Problem: Next, you'll want to break down the problem into smaller, more manageable questions whose answers can be reasonably estimated. For the piano tuner question, you might ask:

- How many people live in New York City?
- How many households does that represent?
- What fraction of households own a piano?
- How often does a piano need to be tuned each year?
- How many pianos can one tuner handle in a year?
3. Make Estimates: Now, you'll need to make educated guesses to answer these smaller questions. You can often make a reasonable estimate based on known facts or basic assumptions about the world. For example, you might guess that one in every hundred households in New York City owns a piano, and that a piano needs to be tuned once a year.

4. Perform Calculations: Once you have your estimates, you'll need to perform the necessary calculations to solve the problem. Remember, the goal here isn't to get a perfectly accurate answer, but rather to arrive at a ballpark figure that's within the right order of magnitude. So, if your calculations require complex operations, it's usually okay to round numbers or simplify to make the math easier.

5. Review and Refine: Finally, you should always review your estimates and calculations to see if they make sense. If your answer seems unreasonable, you should go back and check your work, refine your estimates, or consider whether there are other aspects of the problem you haven't taken into account.

Fermi estimation is an incredibly valuable tool for developing problem-solving skills and enhancing critical thinking. It encourages making reasonable assumptions, simplifying complex problems, and approximating – all crucial skills in a wide range of fields.'''

round_2_recursion = '''This is a very structured approach. I am interested in the second step, which is breaking down a problem into sub-problems. This is a recursive step. Can you explain the concept of recursion?'''
round_2_response = '''Recursion is a fundamental concept in computer science, mathematics, and broader problem-solving that involves breaking a complex problem into smaller, manageable subproblems. The solution to the original problem is then constructed from the solutions of these subproblems.

A recursive process has two key components: a base case and a recursive case. The base case is a condition that terminates the recursion, providing a direct solution without self-referencing. In contrast, the recursive case involves the function calling itself with smaller instances of the problem, leading towards the base case with each step.

For example, a recursive function for calculating factorials in programming would include a base case (if n equals 0, return 1) and a recursive case (return n multiplied by the factorial of n-1). This function continually calls itself, moving closer to the base case each time, until it can start returning values.

In Fermi estimation and similar problem-solving methods, recursion entails breaking the problem down into subproblems until they can be easily solved or estimated. This 'divide and conquer' approach helps navigate complex problems, with the solutions to subproblems combined to solve larger ones, eventually addressing the original problem.'''

round_3_piano_tuners_explained = '''In the case of the classic piano tuner problem, would you explain how recursion is applied here?'''
round_3_response = '''In the case of the piano tuner problem, the application of recursion isn't as pronounced as in a mathematical function or computer algorithm, but the concept of "breaking down a problem into sub-problems until they are solvable" is present, which aligns with the general idea of recursion.

The original problem is: "How many piano tuners are there in New York City?" This is a difficult problem to answer directly due to the lack of readily available data, so we break it down into smaller problems. Here's how that might look:

Estimate the population of New York City: This is a base problem we can solve with known data. As of my knowledge cutoff in 2021, the population of New York City was over 8 million people.

Estimate the number of households in New York City: This is a smaller problem we can estimate with a reasonable assumption. For instance, we could assume an average of 2.5 people per household, which is roughly the average household size in the United States.

Estimate the proportion of households with a piano: This is another smaller problem. We might not have an exact answer, but we can make a reasonable guess. Maybe 1 in every 50 households has a piano.

Estimate the number of times a piano needs tuning per year: Yet another smaller problem. A piano might need to be tuned once or twice a year.

Estimate the number of pianos a tuner can service in a year: This is the final smaller problem. A piano tuner might be able to tune 2 pianos a day, working 5 days a week, for 50 weeks a year.

Each of these smaller problems contributes to the solution of the larger problem. Once we have estimates for each of these, we can combine them to find the total estimated number of piano tuners in New York City. This process is similar to recursion in that we're continually breaking down the problem into smaller, solvable problems until we're able to solve the original, more complex problem.'''

counter = 0
question_bank = []
while counter < 10:
    # check if the question is already in the bank
    new_question = generate_market_sizing_question()
    if new_question not in question_bank:
            question_bank.append(new_question)
            counter += 1
print(question_bank)
# Out:
# ['How many nurseries are there in Tokyo?', 'How many gas stations are there in Los Angeles?', 'How many schools are there in Beijing?', 'How many nurseries are there in Mumbai?', 'How many barber shops are there in London?', 'How many libraries are there in Paris?', 'How many coffee shops are there in Beijing?', 'How many coffee shops are there in New York?', 'How many hotels are there in Chicago?', 'How many piano tuners are there in New York?']

# %%
def apply_concept_recursion(chat_messages, model="gpt-4-0314", get_completion_from_messages=get_completion_from_messages):
    '''Query OpenAI API to answer a question using recursion'''
    result = get_completion_from_messages(chat_messages, model=model) # returns a string
    return result

# %% [markdown]
# ## Question inference (with GPT4 model)

# %%
# generate a question bank of 100 questions
df = pd.DataFrame(columns=['question', 'answer_after_warm_up', 'answer_json', 'answer_python'])
timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
for index, each_question in enumerate(question_bank):
    question_prompt = f'''That's very helpful. Now let's consider another problem: {each_question} - how would you apply the concept of recursion to arrive at an answer?
Can you use your estimation trick and recursively break the problem down until you can confidently provide a rough estimation?'''
    warmed_messages = [{"role": "system", "content": you_are_fermi},
            {"role": "user", "content": round_1_fermi},
            {"role": "system", "content": round_1_response},
            {"role": "user", "content": round_2_recursion},
            {"role": "system", "content": round_2_response},
            {"role": "user", "content": round_3_piano_tuners_explained},
            {"role": "system", "content": round_3_response},
            {"role": "user", "content": question_prompt}
            ]
    print(each_question)
    print(f"""No. of token used: {num_tokens_from_messages(warmed_messages)}""")
    answer = apply_concept_recursion(warmed_messages)
    print(answer)
    print(f"<<<<Completed Question {index} in question bank<<<<")
    answer_json = text_to_json(answer)
    print(f"<<<<Received Response to Question {index} <<<<")
    python_message = text_to_python(answer)
    print(f"<<<<Received Python Code to Question {index} <<<<")
    # append the new data to the end of the dataframe
    row = [each_question, answer, answer_json, python_message]
    df.loc[len(df)] = row

df.to_csv(f'market_sizing_question_{timestamp}.csv', index=False)
print(question_bank)
print(answer)
print(get_json(answer_json))
print(get_python(python_message))

## get_answer_step_by_step is about 35s per question
## get_json is about 15s per question
## get_python is about 25s per question
# total = 75s per question
# Out:
# How many nurseries are there in Tokyo?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1358
# Sure! Let's apply the Fermi estimation technique and recursively break down the problem of estimating the number of nurseries in Tokyo.
#
# 1. Define the Problem Clearly: "How many nurseries are there in Tokyo?"
#
# 2. Break Down the Problem: We'll need to break this problem into smaller, more manageable questions. Here are some possible questions to consider:
#
# - What is the population of Tokyo?
# - What percentage of the population are children of nursery age?
# - What is the average number of children per nursery?
#
# 3. Make Estimates: Now, we'll make educated guesses to answer these smaller questions.
#
# - Population of Tokyo: As of my knowledge cutoff in 2021, the population of Tokyo was around 14 million people.
# - Percentage of the population of nursery age: Let's assume that nursery age is from 0 to 4 years old. According to World Bank data, the percentage of the population aged 0-4 in Japan is around 4.5%. We'll use this percentage for Tokyo as well.
# - Average number of children per nursery: This number can vary, but let's assume an average of 50 children per nursery.
#
# 4. Perform Calculations: With these estimates, we can now perform the necessary calculations.
#
# - Number of children of nursery age in Tokyo: 14,000,000 (population) * 0.045 (percentage of nursery age) = 630,000 children
# - Number of nurseries in Tokyo: 630,000 children / 50 children per nursery = 12,600 nurseries
#
# 5. Review and Refine: Our rough estimation suggests there are around 12,600 nurseries in Tokyo. This is a ballpark figure, and the actual number may be different. However, this estimation gives us a starting point and an idea of the order of magnitude.
#
# Remember that Fermi estimation is about making reasonable assumptions and approximations. The actual number of nurseries in Tokyo may be different, but this method helps us arrive at a rough estimate using the available information and logical assumptions.
# <<<<Completed Question 0 in question bank<<<<
# <<<<Received Response to Question 0 <<<<
# <<<<Received Python Code to Question 0 <<<<
# How many gas stations are there in Los Angeles?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1359
# Sure! Let's apply the Fermi estimation technique to estimate the number of gas stations in Los Angeles. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to answer them.
#
# 1. Estimate the population of Los Angeles: As of my knowledge cutoff in 2021, the population of Los Angeles was around 4 million people.
#
# 2. Estimate the number of cars in Los Angeles: We can assume that there is a certain number of cars per household. According to the U.S. Department of Transportation, there are about 1.88 vehicles per household in the United States. Let's assume there are 2 cars per household in Los Angeles. With an average of 2.5 people per household, there would be around 1.6 million households in Los Angeles. Therefore, we can estimate that there are approximately 3.2 million cars in the city.
#
# 3. Estimate the average distance a car travels per day: According to the U.S. Department of Transportation, the average American drives about 13,500 miles per year. Assuming 365 days in a year, that's roughly 37 miles per day.
#
# 4. Estimate the average fuel efficiency of cars: Let's assume the average fuel efficiency of cars in Los Angeles is 25 miles per gallon.
#
# 5. Estimate the average fuel tank capacity: We can assume the average fuel tank capacity is around 15 gallons.
#
# 6. Estimate how often a car needs to refuel: With an average fuel efficiency of 25 miles per gallon and a 15-gallon tank, a car can travel approximately 375 miles before needing to refuel. If a car travels 37 miles per day, it would need to refuel every 375/37 ≈ 10 days.
#
# 7. Estimate the time it takes to refuel a car: Let's assume it takes about 5 minutes to refuel a car.
#
# 8. Estimate the number of cars a gas station can serve per day: Assuming a gas station has 4 pumps and is open 12 hours a day, it can serve 4 cars every 5 minutes, or 48 cars per hour. Over 12 hours, a gas station can serve 48 * 12 = 576 cars.
#
# 9. Estimate the total number of refueling events per day in Los Angeles: With 3.2 million cars and each car refueling every 10 days, there would be 3.2 million / 10 ≈ 320,000 refueling events per day.
#
# 10. Estimate the number of gas stations needed to serve the demand: If each gas station can serve 576 cars per day, we would need 320,000 / 576 ≈ 556 gas stations to serve the demand.
#
# Based on these assumptions and calculations, we can estimate that there are approximately 556 gas stations in Los Angeles. Keep in mind that this is a rough estimation, and the actual number may vary depending on the accuracy of our assumptions.
# <<<<Completed Question 1 in question bank<<<<
# <<<<Received Response to Question 1 <<<<
# <<<<Received Python Code to Question 1 <<<<
# How many schools are there in Beijing?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1357
# Sure! Let's apply the Fermi estimation technique to estimate the number of schools in Beijing. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to answer them.
#
# 1. Estimate the population of Beijing: As of my knowledge cutoff in 2021, the population of Beijing was over 21 million people.
#
# 2. Estimate the proportion of the population that is school-aged: We can assume that around 20% of the population is school-aged (from kindergarten to high school), which is a rough estimate based on global age distribution patterns.
#
# 3. Estimate the average number of students per school: This can vary greatly depending on the type of school and location, but let's assume an average of 1,000 students per school. This is a rough estimate that takes into account both small and large schools.
#
# Now, we can perform the calculations:
#
# 1. Calculate the number of school-aged children in Beijing: 21 million people * 20% = 4.2 million school-aged children.
#
# 2. Calculate the number of schools needed to accommodate these students: 4.2 million school-aged children / 1,000 students per school = 4,200 schools.
#
# So, based on these rough estimates and assumptions, there could be around 4,200 schools in Beijing. Keep in mind that this is a Fermi estimation, and the actual number may be different. However, this approach gives us a ballpark figure that can be useful for problem-solving and decision-making.
# <<<<Completed Question 2 in question bank<<<<
# <<<<Received Response to Question 2 <<<<
# <<<<Received Python Code to Question 2 <<<<
# How many nurseries are there in Mumbai?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1358
# Sure! Let's apply the Fermi estimation technique and break down the problem of estimating the number of nurseries in Mumbai into smaller, more manageable questions. Here's one possible approach:
#
# 1. Estimate the population of Mumbai: As of my knowledge cutoff in 2021, the population of Mumbai was around 20 million people.
#
# 2. Estimate the proportion of the population that is of nursery-going age: We can assume that children between the ages of 2 and 4 attend nurseries. According to the World Bank, about 25% of India's population is under the age of 14. We can further assume that the age distribution is roughly uniform, so the proportion of children between 2 and 4 would be about 25% * (3/14) ≈ 5.4%.
#
# 3. Calculate the number of children of nursery-going age in Mumbai: Multiply the population of Mumbai by the proportion of children between 2 and 4 years old: 20,000,000 * 5.4% ≈ 1,080,000 children.
#
# 4. Estimate the average number of children per nursery: This is a smaller problem we can estimate with a reasonable assumption. Let's assume that each nursery can accommodate an average of 50 children.
#
# 5. Calculate the number of nurseries in Mumbai: Divide the number of children of nursery-going age by the average number of children per nursery: 1,080,000 children / 50 children per nursery ≈ 21,600 nurseries.
#
# So, using Fermi estimation and breaking down the problem recursively, we can estimate that there are approximately 21,600 nurseries in Mumbai. Keep in mind that this is a rough estimation, and the actual number may vary depending on the accuracy of our assumptions and the data available.
# <<<<Completed Question 3 in question bank<<<<
# <<<<Received Response to Question 3 <<<<
# <<<<Received Python Code to Question 3 <<<<
# How many barber shops are there in London?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1358
# Sure! Let's apply the Fermi estimation technique and break down the problem of estimating the number of barber shops in London into smaller, more manageable subproblems.
#
# 1. Estimate the population of London: As of my knowledge cutoff in 2021, the population of London was around 9 million people.
#
# 2. Estimate the number of households in London: We can assume an average of 2.5 people per household, similar to the previous example. This would give us approximately 3.6 million households (9 million / 2.5).
#
# 3. Estimate the proportion of the population that needs barber services: We can assume that both men and women visit barber shops, but men might visit more frequently. Let's assume that 60% of the population needs barber services regularly.
#
# 4. Estimate the frequency of barber shop visits: Let's assume that the average person who visits a barber shop does so once every 6 weeks, or roughly 8.7 times a year (52 weeks / 6).
#
# 5. Estimate the number of customers a barber shop can serve in a day: Let's assume that a barber shop has 3 barbers, each of whom can serve 10 customers per day. This means a barber shop can serve 30 customers per day.
#
# 6. Estimate the number of days a barber shop is open per year: Let's assume that a barber shop is open 6 days a week for 50 weeks a year, which is 300 days.
#
# Now, we can use these estimates to calculate the number of barber shops in London:
#
# 1. Calculate the number of people who need barber services: 9 million * 0.6 = 5.4 million people
# 2. Calculate the total number of barber visits per year: 5.4 million * 8.7 = 46.98 million visits
# 3. Calculate the total number of customers a barber shop can serve per year: 30 customers/day * 300 days = 9,000 customers/year
# 4. Estimate the number of barber shops needed to serve the population: 46.98 million visits / 9,000 customers/year = 5,220 barber shops
#
# So, using Fermi estimation and breaking down the problem recursively, we can estimate that there are approximately 5,220 barber shops in London. Keep in mind that this is a rough estimation and the actual number may vary.
# <<<<Completed Question 4 in question bank<<<<
# <<<<Received Response to Question 4 <<<<
# <<<<Received Python Code to Question 4 <<<<
# How many libraries are there in Paris?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1357
# Sure! Let's apply the Fermi estimation technique to estimate the number of libraries in Paris. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to answer them.
#
# 1. Estimate the population of Paris: As of my knowledge cutoff in 2021, the population of Paris is around 2.1 million people.
#
# 2. Estimate the number of people served by a single library: We can make a reasonable assumption that a library serves a certain number of people in its vicinity. Let's assume that one library serves around 20,000 people.
#
# Now, we can perform a simple calculation to estimate the number of libraries in Paris:
#
# Number of libraries = (Population of Paris) / (Number of people served by a single library)
#
# Number of libraries = 2,100,000 / 20,000
#
# Number of libraries ≈ 105
#
# So, based on our assumptions and calculations, we can estimate that there are roughly 105 libraries in Paris. Keep in mind that this is just an approximation, and the actual number may be different. However, this estimation should give you a ballpark figure that's within the right order of magnitude.
# <<<<Completed Question 5 in question bank<<<<
# <<<<Received Response to Question 5 <<<<
# <<<<Received Python Code to Question 5 <<<<
# How many coffee shops are there in Beijing?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1358
# Sure! Let's apply the Fermi estimation technique to estimate the number of coffee shops in Beijing. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to answer them.
#
# 1. Estimate the population of Beijing: As of my knowledge cutoff in 2021, the population of Beijing was over 21 million people.
#
# 2. Estimate the number of people per coffee shop: We need to make an assumption about how many people are served by a single coffee shop. Let's assume that one coffee shop serves 2,000 people. This is a rough estimate based on the idea that not everyone drinks coffee, and some people might make their coffee at home or at work.
#
# 3. Calculate the number of coffee shops: Now that we have estimates for the population of Beijing and the number of people per coffee shop, we can calculate the number of coffee shops. Divide the population by the number of people per coffee shop:
#
#    21,000,000 people / 2,000 people per coffee shop = 10,500 coffee shops
#
# So, based on our assumptions and estimates, there might be around 10,500 coffee shops in Beijing.
#
# Keep in mind that this is a rough estimate, and the actual number could be higher or lower depending on factors such as the popularity of coffee in Beijing, the presence of other beverage options, and the density of coffee shops in different areas of the city. The key takeaway is that Fermi estimation and recursion can help us arrive at a ballpark figure even when we don't have exact data.
# <<<<Completed Question 6 in question bank<<<<
# <<<<Received Response to Question 6 <<<<
# <<<<Received Python Code to Question 6 <<<<
# How many coffee shops are there in New York?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1359
# Sure! Let's apply the concept of breaking down the problem into smaller, more manageable subproblems to estimate the number of coffee shops in New York City.
#
# 1. Estimate the population of New York City: As mentioned earlier, the population of New York City is over 8 million people.
#
# 2. Estimate the number of people per coffee shop: We need to make a reasonable assumption about how many people a single coffee shop serves. Let's assume that one coffee shop serves 1,000 people. This number is a rough estimate and can vary depending on the location and density of coffee shops.
#
# 3. Calculate the number of coffee shops based on population: Now, we can divide the population of New York City by the number of people served by one coffee shop to estimate the total number of coffee shops.
#
#    8,000,000 people / 1,000 people per coffee shop = 8,000 coffee shops
#
# This estimate of 8,000 coffee shops in New York City is a rough approximation based on our assumptions. Keep in mind that the actual number could be higher or lower depending on factors such as the density of coffee shops in different neighborhoods, the popularity of coffee consumption, and the presence of non-traditional coffee-serving establishments (e.g., restaurants, cafes, etc.).
#
# In this case, the recursion isn't as deep as in some other problems, but the general idea of breaking down the problem into smaller, solvable subproblems is still present. We made a reasonable assumption about the number of people served by one coffee shop and used that to estimate the total number of coffee shops based on the population of New York City.
# <<<<Completed Question 7 in question bank<<<<
# <<<<Received Response to Question 7 <<<<
# <<<<Received Python Code to Question 7 <<<<
# How many hotels are there in Chicago?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1357
# Sure! Let's apply the Fermi estimation technique to estimate the number of hotels in Chicago. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to answer them.
#
# 1. Estimate the population of Chicago: As of my knowledge cutoff in 2021, the population of Chicago was around 2.7 million people.
#
# 2. Estimate the number of tourists visiting Chicago annually: According to data from previous years, Chicago attracts around 50 million tourists annually. However, not all of them would need hotel accommodations, as some may stay with friends or family, or use alternative accommodations like Airbnb. Let's assume that 60% of tourists would need hotel accommodations, which would be around 30 million tourists.
#
# 3. Estimate the average length of stay for a tourist: We can assume that the average tourist stays for about 3 days (or 0.0082 years, considering a year has 365 days).
#
# 4. Estimate the average hotel occupancy rate: Hotel occupancy rates can vary, but let's assume an average occupancy rate of 70%.
#
# 5. Estimate the average number of hotel rooms per hotel: This can vary greatly depending on the size of the hotel, but let's assume an average of 100 rooms per hotel.
#
# Now, let's perform the calculations:
#
# 1. Calculate the total number of tourist-nights per year: 30 million tourists * 3 days = 90 million tourist-nights.
#
# 2. Calculate the total number of hotel rooms needed to accommodate tourists: 90 million tourist-nights / (365 days * 0.7 occupancy rate) ≈ 351,351 rooms.
#
# 3. Estimate the number of hotels in Chicago: 351,351 rooms / 100 rooms per hotel ≈ 3,514 hotels.
#
# So, based on these assumptions and calculations, there could be approximately 3,514 hotels in Chicago. Keep in mind that this is a rough estimation, and the actual number may vary depending on the accuracy of the assumptions made.
# <<<<Completed Question 8 in question bank<<<<
# <<<<Received Response to Question 8 <<<<
# <<<<Received Python Code to Question 8 <<<<
# How many piano tuners are there in New York?
# Warning: gpt-4 may change over time. Returning num tokens assuming gpt-4-0314.
# No. of token used: 1360
# Certainly! Let's apply the concept of recursion and Fermi estimation to estimate the number of piano tuners in New York State. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to estimate the answer.
#
# 1. Estimate the population of New York State: As of my knowledge cutoff in 2021, the population of New York State was around 20 million people.
#
# 2. Estimate the number of households in New York State: Assuming an average of 2.5 people per household (similar to the national average), we can estimate there are about 8 million households in New York State (20 million people / 2.5 people per household).
#
# 3. Estimate the proportion of households with a piano: We'll use the same assumption as before, that 1 in every 50 households has a piano. This gives us an estimated 160,000 pianos in New York State (8 million households / 50).
#
# 4. Estimate the number of times a piano needs tuning per year: We'll assume a piano needs to be tuned once a year on average.
#
# 5. Estimate the number of pianos a tuner can service in a year: We'll use the same assumption as before, that a piano tuner can tune 2 pianos a day, working 5 days a week, for 50 weeks a year. This means a piano tuner can service 500 pianos a year (2 pianos/day * 5 days/week * 50 weeks/year).
#
# 6. Estimate the number of piano tuners in New York State: Now we can estimate the number of piano tuners needed to service all the pianos in New York State. We have 160,000 pianos that need tuning once a year, and each tuner can service 500 pianos a year. So, we would need 320 piano tuners to service all the pianos in New York State (160,000 pianos / 500 pianos per tuner).
#
# This is a rough estimation, and the actual number of piano tuners in New York State may be different. However, this recursive approach and Fermi estimation give us a ballpark figure that helps us understand the scale of the problem.
# <<<<Completed Question 9 in question bank<<<<
# <<<<Received Response to Question 9 <<<<
# <<<<Received Python Code to Question 9 <<<<
# ['How many nurseries are there in Tokyo?', 'How many gas stations are there in Los Angeles?', 'How many schools are there in Beijing?', 'How many nurseries are there in Mumbai?', 'How many barber shops are there in London?', 'How many libraries are there in Paris?', 'How many coffee shops are there in Beijing?', 'How many coffee shops are there in New York?', 'How many hotels are there in Chicago?', 'How many piano tuners are there in New York?']
# Certainly! Let's apply the concept of recursion and Fermi estimation to estimate the number of piano tuners in New York State. We'll break the problem down into smaller, more manageable questions and make reasonable assumptions to estimate the answer.
#
# 1. Estimate the population of New York State: As of my knowledge cutoff in 2021, the population of New York State was around 20 million people.
#
# 2. Estimate the number of households in New York State: Assuming an average of 2.5 people per household (similar to the national average), we can estimate there are about 8 million households in New York State (20 million people / 2.5 people per household).
#
# 3. Estimate the proportion of households with a piano: We'll use the same assumption as before, that 1 in every 50 households has a piano. This gives us an estimated 160,000 pianos in New York State (8 million households / 50).
#
# 4. Estimate the number of times a piano needs tuning per year: We'll assume a piano needs to be tuned once a year on average.
#
# 5. Estimate the number of pianos a tuner can service in a year: We'll use the same assumption as before, that a piano tuner can tune 2 pianos a day, working 5 days a week, for 50 weeks a year. This means a piano tuner can service 500 pianos a year (2 pianos/day * 5 days/week * 50 weeks/year).
#
# 6. Estimate the number of piano tuners in New York State: Now we can estimate the number of piano tuners needed to service all the pianos in New York State. We have 160,000 pianos that need tuning once a year, and each tuner can service 500 pianos a year. So, we would need 320 piano tuners to service all the pianos in New York State (160,000 pianos / 500 pianos per tuner).
#
# This is a rough estimation, and the actual number of piano tuners in New York State may be different. However, this recursive approach and Fermi estimation give us a ballpark figure that helps us understand the scale of the problem.
# {"problem": "Estimating the number of piano tuners in New York State using recursion and Fermi estimation.", "steps": {"Step 1": "Estimate the population of New York State, which is around 20 million people.", "Step 2": "Estimate the number of households in New York State, which is around 8 million households assuming an average of 2.5 people per household.", "Step 3": "Estimate the proportion of households with a piano, which is 1 in every 50 households, giving us an estimated 160,000 pianos in New York State.", "Step 4": "Estimate the number of times a piano needs tuning per year, which is once a year on average.", "Step 5": "Estimate the number of pianos a tuner can service in a year, which is 500 pianos a year assuming a tuner can tune 2 pianos a day, working 5 days a week, for 50 weeks a year.", "Step 6": "Estimate the number of piano tuners in New York State, which is 320 piano tuners needed to service all the pianos in New York State assuming 160,000 pianos that need tuning once a year, and each tuner can service 500 pianos a year."}, "assumptions": "This is a rough estimation, and the actual number of piano tuners in New York State may be different. However, this recursive approach and Fermi estimation give us a ballpark figure that helps us understand the scale of the problem."}
# # Step 1: Estimate the population of New York State
# population_new_york_state = 20000000  # 20 million people
#
# # Step 2: Estimate the number of households in New York State
# average_people_per_household = 2.5
# households_new_york_state = population_new_york_state / average_people_per_household
#
# # Step 3: Estimate the proportion of households with a piano
# piano_household_ratio = 50
# pianos_new_york_state = households_new_york_state / piano_household_ratio
#
# # Step 4: Estimate the number of times a piano needs tuning per year
# piano_tuning_frequency = 1  # Once a year
#
# # Step 5: Estimate the number of pianos a tuner can service in a year
# pianos_per_day = 2
# days_per_week = 5
# weeks_per_year = 50
# pianos_per_tuner_per_year = pianos_per_day * days_per_week * weeks_per_year
#
# # Step 6: Estimate the number of piano tuners in New York State
# piano_tuners_new_york_state = pianos_new_york_state / pianos_per_tuner_per_year
#
# # Print the result
# print(f"An estimated {piano_tuners_new_york_state:.0f} piano tuners are needed to service all the pianos in New York State.")

# %%
# apply a function to the column "answer_python" for each row
# df[df['name'].apply(lambda x: is_long(x) & is_short(x))]
for index, row in df.iterrows():
    # print(row['answer_python'])
    exec(get_python(df['answer_python'][index]))
# Out:
# There are approximately 12600 nurseries in Tokyo.
# Based on the assumptions and calculations, there are approximately 548 gas stations in Los Angeles.
# Based on the Fermi estimation, there could be around 4200 schools in Beijing.
# There are approximately 21600 nurseries in Mumbai.
# Using Fermi estimation, there are approximately 5220 barber shops in London.
# There are approximately 105 libraries in Paris.
# There might be around 10500 coffee shops in Beijing.
# Based on our assumptions, there are approximately 8000 coffee shops in New York City.
# There could be approximately 3523 hotels in Chicago based on these assumptions and calculations.
# An estimated 320 piano tuners are needed to service all the pianos in New York State.

# %%
df.to_csv('market_sizing_question.csv', index=False)

# %%
# exec code directly will be dangerous, so we use exec to run the code in a sandbox
#exec(get_python(python_message))
# just print the message will do : )

# %%
# Best practices:
# https://platform.openai.com/docs/guides/gpt-best-practices/strategy-split-complex-tasks-into-simpler-subtasks

# Strategy: Split complex tasks into simpler subtasks

# %%
# Strategy: Use a persona

# %%
# Strategy: User inner monologue
# instruct the model to put parts of the output that are meant to be hidden from the user into a structured format
# makes parsing them easy. 

# before presenting the output to the user, the output is parsed and only part of the output is made visible.

system_message_IM_example = '''Follow these steps to answer the user queries.

Step 1 - First work out your own solution to the problem. Don't rely on the student's solution since it may be incorrect. Enclose all your work for this step within triple quotes (""").

Step 2 - Compare your solution to the student's solution and evaluate if the student's solution is correct or not. Enclose all your work for this step within triple quotes (""").

Step 3 - If the student made a mistake, determine what hint you could give the student without giving away the answer. Enclose all your work for this step within triple quotes (""").

Step 4 - If the student made a mistake, provide the hint from the previous step to the student (outside of triple quotes). Instead of writing "Step 4 - ..." write "Hint:".'''
